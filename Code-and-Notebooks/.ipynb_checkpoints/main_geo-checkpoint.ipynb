# %%
# Run in terminal:
conda install geopandas pyproj rtree
conda install pandas fiona shapely #<- run this line if they aren't automatically installed with geopandas
conda install -c conda-forge descartes

# %%
import geo
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# Create geopandas dataframe
world = geo.create_world('./Datasets/train.csv', './Datasets/test.csv')
print('done')
# Out:
# done

# %%
# Plot results
fig, ax = plt.subplots(1, 1)
plt.title("Fake News Heat Map")
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.5)
world.plot(column='Mentions_Fake', missing_kwds={'color': 'lightgrey'}, cmap = 'OrRd', ax=ax, legend=True, cax = cax, vmin = -200, vmax = 2000)
fig.set_size_inches(20, 15)
#plt.savefig('fake_world.jpeg')

fig2, ax2 = plt.subplots(1, 1)
plt.title("Real News Heat Map")
divider = make_axes_locatable(ax2)
cax2 = divider.append_axes("right", size="5%", pad=0.5)
world.plot(column='Mentions_Real', missing_kwds={'color': 'lightgrey'}, cmap = 'OrRd', ax=ax2, legend=True, cax = cax2, vmin = -300, vmax = 3500)
fig2.set_size_inches(20, 15)
#plt.savefig('real_world.jpeg')
